# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config1 import g_key

# Configure gmaps API key
gmaps.configure(api_key=g_key)

# %%
# 1. Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv(r"C:\Users\mihpa\Class\World_Weather_Analysis\Weather_Database\WeatherPy_Database.csv")
city_data_df
# Out:
#     Unnamed: 0                   City Country      Lat       Lng  Max Temp  \
# 0            0                 Lompoc      US  34.6391 -120.4579     69.80
# 1            1              Busselton      AU -33.6500  115.3333     63.00
# 2            2            Tuktoyaktuk      CA  69.4541 -133.0374     -4.00
# 3            3              Stornoway      GB  58.2093   -6.3865     44.60
# 4            4              Saskylakh      RU  71.9167  114.0833    -11.79
# 5            5           Port Lincoln      AU -34.7333  135.8667     60.78
# 6            6  Los Llanos de Aridane      ES  28.6585  -17.9182     68.00
# 7            7      Saint Paul Harbor      US  57.7900 -152.4072     39.20
# 8            8             Phan Thiet      VN  10.9333  108.1000     70.09
# 9            9           Punta Arenas      CL -53.1500  -70.9167     60.80
# 10          10            Komsomolets      KZ  53.7453   62.0708     21.45
# 11          11                Sheksna      RU  59.2100   38.5107     -7.60
# 12          12              Flin Flon      CA  54.7682 -101.8650     14.00
# 13          13            New Norfolk      AU -42.7826  147.0587     48.99
# 14          14               Bengkulu      ID  -3.8004  102.2655     77.94
# 15          15          Mar del Plata      AR -38.0023  -57.5575     69.80
# 16          16                   Hilo      US  19.7297 -155.0900     68.00
# 17          17             Butaritari      KI   3.0707  172.7902     80.65
# 18          18             Port Blair      IN  11.6667   92.7500     77.74
# 19          19                Ushuaia      AR -54.8000  -68.3000     60.80
# 20          20                  Rocha      UY -34.4833  -54.3333     83.95
# 21          21                 Albany      US  42.6001  -73.9662     36.00
# 22          22              Ilulissat      GL  69.2167  -51.1000     10.40
# 23          23                Rikitea      PF -23.1203 -134.9692     77.63
# 24          24              Esperance      AU -33.8667  121.9000     55.40
# 25          25                Itarema      BR  -2.9248  -39.9167     88.32
# 26          26             Lavrentiya      RU  65.5833 -171.0000     -5.40
# 27          27                Honiara      SB  -9.4333  159.9500     77.22
# 28          28          Alice Springs      AU -23.7000  133.8833     69.80
# 29          29                Maturin      VE   9.7500  -63.1767     85.05
# 30          30                 Barrow      US  71.2906 -156.7887     -2.20
# 31          31          Mount Gambier      AU -37.8333  140.7667     50.00
# 32          32               Khatanga      RU  71.9667  102.5000    -26.01
# 33          33              Upernavik      GL  72.7868  -56.1549     11.53
# 34          34                 Caniço      PT  32.6333  -16.8500     64.40
# 35          35               Portland      US  45.5234 -122.6762     43.00
# 36          36                 Hirara      JP  24.8000  125.2833     64.94
# 37          37                 Faanui      PF -16.4833 -151.7500     81.23
# 38          38         Ribeira Grande      PT  38.5167  -28.7000     62.60
# 39          39              Hong Kong      HK  22.2855  114.1577     62.01
# 40          40                Kahului      US  20.8947 -156.4700     72.00
# 41          41        Arraial do Cabo      BR -22.9661  -42.0278     87.80
# 42          42               Cherskiy      RU  68.7500  161.3000    -20.74
# 43          43               Sterling      US  39.0062  -77.4286     42.01
# 44          44                  Pisco      PE -13.7000  -76.2167     73.40
# 45          45                Ternate      ID   0.8000  127.4000     78.64
# 46          46                Kavieng      PG  -2.5744  150.7967     82.99
#
#     Humidity  Cloudiness  Wind Speed Current Description
# 0         76          21        8.79          few clouds
# 1         68           0        5.99           clear sky
# 2         77          90       11.50          light snow
# 3         81          75       25.32       broken clouds
# 4         89         100        8.28     overcast clouds
# 5         75          85        7.65     overcast clouds
# 6         64          20        9.22          few clouds
# 7         93          90       33.38       moderate rain
# 8         86          99        7.38     overcast clouds
# 9         59          90       20.71     overcast clouds
# 10        94          38       13.56    scattered clouds
# 11        77           0        8.95           clear sky
# 12        92          75        5.75       broken clouds
# 13        67          38        1.99    scattered clouds
# 14        80         100        3.49     overcast clouds
# 15        94          75        8.05       broken clouds
# 16        73          90        6.91     overcast clouds
# 17        79          52       20.92       broken clouds
# 18        76          59        8.84       broken clouds
# 19        63          40        8.05    scattered clouds
# 20        56          48       12.71    scattered clouds
# 21        89         100        3.47     overcast clouds
# 22        52           1        3.44           clear sky
# 23        71          31        3.49          light rain
# 24        71           0       10.36           clear sky
# 25        54          27       16.31    scattered clouds
# 26        87         100        8.30     overcast clouds
# 27        80         100        2.26     overcast clouds
# 28        46          90        8.05     overcast clouds
# 29        55          36        8.79    scattered clouds
# 30        78          90       18.41                haze
# 31        93          90        5.75     overcast clouds
# 32        86          95        4.50     overcast clouds
# 33        92          13        4.36          few clouds
# 34        52          40       10.36    scattered clouds
# 35        81          90        6.91     overcast clouds
# 36        81          94       30.36     overcast clouds
# 37        73          10       11.01           clear sky
# 38        82          40        8.05    scattered clouds
# 39        76          99        3.00     overcast clouds
# 40        72          20        5.75          few clouds
# 41        58          40       20.71    scattered clouds
# 42        87         100        4.41     overcast clouds
# 43        65          90       11.50     overcast clouds
# 44        73           0        9.22           clear sky
# 45        84         100        2.59          light rain
# 46        80          93       16.64     overcast clouds

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria 
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 40
# What is the maximum temperature you would like for your trip? 95

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.
clean_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                            (city_data_df["Max Temp"] >= min_temp)]
clean_df.head()
# Out:
#    Unnamed: 0                   City Country      Lat       Lng  Max Temp  \
# 0           0                 Lompoc      US  34.6391 -120.4579     69.80
# 1           1              Busselton      AU -33.6500  115.3333     63.00
# 3           3              Stornoway      GB  58.2093   -6.3865     44.60
# 5           5           Port Lincoln      AU -34.7333  135.8667     60.78
# 6           6  Los Llanos de Aridane      ES  28.6585  -17.9182     68.00
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        76          21        8.79          few clouds
# 1        68           0        5.99           clear sky
# 3        81          75       25.32       broken clouds
# 5        75          85        7.65     overcast clouds
# 6        64          20        9.22          few clouds

# %%
# 4a. Determine if there are any empty rows.
clean_df.isnull().sum()
# Out:
# Unnamed: 0             0
# City                   0
# Country                0
# Lat                    0
# Lng                    0
# Max Temp               0
# Humidity               0
# Cloudiness             0
# Wind Speed             0
# Current Description    0
# dtype: int64

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
clean_df = clean_df.dropna()
clean_df
# Out:
#     Unnamed: 0                   City Country      Lat       Lng  Max Temp  \
# 0            0                 Lompoc      US  34.6391 -120.4579     69.80
# 1            1              Busselton      AU -33.6500  115.3333     63.00
# 3            3              Stornoway      GB  58.2093   -6.3865     44.60
# 5            5           Port Lincoln      AU -34.7333  135.8667     60.78
# 6            6  Los Llanos de Aridane      ES  28.6585  -17.9182     68.00
# 8            8             Phan Thiet      VN  10.9333  108.1000     70.09
# 9            9           Punta Arenas      CL -53.1500  -70.9167     60.80
# 13          13            New Norfolk      AU -42.7826  147.0587     48.99
# 14          14               Bengkulu      ID  -3.8004  102.2655     77.94
# 15          15          Mar del Plata      AR -38.0023  -57.5575     69.80
# 16          16                   Hilo      US  19.7297 -155.0900     68.00
# 17          17             Butaritari      KI   3.0707  172.7902     80.65
# 18          18             Port Blair      IN  11.6667   92.7500     77.74
# 19          19                Ushuaia      AR -54.8000  -68.3000     60.80
# 20          20                  Rocha      UY -34.4833  -54.3333     83.95
# 23          23                Rikitea      PF -23.1203 -134.9692     77.63
# 24          24              Esperance      AU -33.8667  121.9000     55.40
# 25          25                Itarema      BR  -2.9248  -39.9167     88.32
# 27          27                Honiara      SB  -9.4333  159.9500     77.22
# 28          28          Alice Springs      AU -23.7000  133.8833     69.80
# 29          29                Maturin      VE   9.7500  -63.1767     85.05
# 31          31          Mount Gambier      AU -37.8333  140.7667     50.00
# 34          34                 Caniço      PT  32.6333  -16.8500     64.40
# 35          35               Portland      US  45.5234 -122.6762     43.00
# 36          36                 Hirara      JP  24.8000  125.2833     64.94
# 37          37                 Faanui      PF -16.4833 -151.7500     81.23
# 38          38         Ribeira Grande      PT  38.5167  -28.7000     62.60
# 39          39              Hong Kong      HK  22.2855  114.1577     62.01
# 40          40                Kahului      US  20.8947 -156.4700     72.00
# 41          41        Arraial do Cabo      BR -22.9661  -42.0278     87.80
# 43          43               Sterling      US  39.0062  -77.4286     42.01
# 44          44                  Pisco      PE -13.7000  -76.2167     73.40
# 45          45                Ternate      ID   0.8000  127.4000     78.64
# 46          46                Kavieng      PG  -2.5744  150.7967     82.99
#
#     Humidity  Cloudiness  Wind Speed Current Description
# 0         76          21        8.79          few clouds
# 1         68           0        5.99           clear sky
# 3         81          75       25.32       broken clouds
# 5         75          85        7.65     overcast clouds
# 6         64          20        9.22          few clouds
# 8         86          99        7.38     overcast clouds
# 9         59          90       20.71     overcast clouds
# 13        67          38        1.99    scattered clouds
# 14        80         100        3.49     overcast clouds
# 15        94          75        8.05       broken clouds
# 16        73          90        6.91     overcast clouds
# 17        79          52       20.92       broken clouds
# 18        76          59        8.84       broken clouds
# 19        63          40        8.05    scattered clouds
# 20        56          48       12.71    scattered clouds
# 23        71          31        3.49          light rain
# 24        71           0       10.36           clear sky
# 25        54          27       16.31    scattered clouds
# 27        80         100        2.26     overcast clouds
# 28        46          90        8.05     overcast clouds
# 29        55          36        8.79    scattered clouds
# 31        93          90        5.75     overcast clouds
# 34        52          40       10.36    scattered clouds
# 35        81          90        6.91     overcast clouds
# 36        81          94       30.36     overcast clouds
# 37        73          10       11.01           clear sky
# 38        82          40        8.05    scattered clouds
# 39        76          99        3.00     overcast clouds
# 40        72          20        5.75          few clouds
# 41        58          40       20.71    scattered clouds
# 43        65          90       11.50     overcast clouds
# 44        73           0        9.22           clear sky
# 45        84         100        2.59          light rain
# 46        80          93       16.64     overcast clouds

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = clean_df[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()

# 5b. Create a new column "Hotel Name"
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#                      City Country  Max Temp Current Description      Lat  \
# 0                  Lompoc      US     69.80          few clouds  34.6391
# 1               Busselton      AU     63.00           clear sky -33.6500
# 3               Stornoway      GB     44.60       broken clouds  58.2093
# 5            Port Lincoln      AU     60.78     overcast clouds -34.7333
# 6   Los Llanos de Aridane      ES     68.00          few clouds  28.6585
# 8              Phan Thiet      VN     70.09     overcast clouds  10.9333
# 9            Punta Arenas      CL     60.80     overcast clouds -53.1500
# 13            New Norfolk      AU     48.99    scattered clouds -42.7826
# 14               Bengkulu      ID     77.94     overcast clouds  -3.8004
# 15          Mar del Plata      AR     69.80       broken clouds -38.0023
#
#          Lng Hotel Name
# 0  -120.4579
# 1   115.3333
# 3    -6.3865
# 5   135.8667
# 6   -17.9182
# 8   108.1000
# 9   -70.9167
# 13  147.0587
# 14  102.2655
# 15  -57.5575

# %%
# 6a. Set parameters to search for hotels with 5000 meters.
params = {
    "radius": 5000,
    "types": "lodging",
    "key": g_key
}

# 6b. Iterate through the hotel DataFrame.
for index, row in hotel_df.iterrows():
#for index, row in hotel_df.iterrows()[:3]: 
    # 6c. Get latitude and longitude from DataFrame
    lat = row["Lat"]
    lng = row["Lng"]
    params["location"] = f"{lat},{lng}"
    
    # 6d. Set up the base URL for the Google Directions API to get JSON data.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # 6e. Make request and retrieve the JSON data from the search. 
    hotels = requests.get(base_url, params=params).json()
    
    # 6f. Get the first hotel from the results and store the name, if a hotel isn't found skip the city.
    try: 
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found...skipping.")

# %%
# 7. Drop the rows where there is no Hotel Name.
clean_hotel_df = hotel_df.dropna()
clean_hotel_df
# Out:
#                      City Country  Max Temp Current Description      Lat  \
# 0                  Lompoc      US     69.80          few clouds  34.6391
# 1               Busselton      AU     63.00           clear sky -33.6500
# 3               Stornoway      GB     44.60       broken clouds  58.2093
# 5            Port Lincoln      AU     60.78     overcast clouds -34.7333
# 6   Los Llanos de Aridane      ES     68.00          few clouds  28.6585
# 8              Phan Thiet      VN     70.09     overcast clouds  10.9333
# 9            Punta Arenas      CL     60.80     overcast clouds -53.1500
# 13            New Norfolk      AU     48.99    scattered clouds -42.7826
# 14               Bengkulu      ID     77.94     overcast clouds  -3.8004
# 15          Mar del Plata      AR     69.80       broken clouds -38.0023
# 16                   Hilo      US     68.00     overcast clouds  19.7297
# 17             Butaritari      KI     80.65       broken clouds   3.0707
# 18             Port Blair      IN     77.74       broken clouds  11.6667
# 19                Ushuaia      AR     60.80    scattered clouds -54.8000
# 20                  Rocha      UY     83.95    scattered clouds -34.4833
# 23                Rikitea      PF     77.63          light rain -23.1203
# 24              Esperance      AU     55.40           clear sky -33.8667
# 25                Itarema      BR     88.32    scattered clouds  -2.9248
# 27                Honiara      SB     77.22     overcast clouds  -9.4333
# 28          Alice Springs      AU     69.80     overcast clouds -23.7000
# 29                Maturin      VE     85.05    scattered clouds   9.7500
# 31          Mount Gambier      AU     50.00     overcast clouds -37.8333
# 34                 Caniço      PT     64.40    scattered clouds  32.6333
# 35               Portland      US     43.00     overcast clouds  45.5234
# 36                 Hirara      JP     64.94     overcast clouds  24.8000
# 37                 Faanui      PF     81.23           clear sky -16.4833
# 38         Ribeira Grande      PT     62.60    scattered clouds  38.5167
# 39              Hong Kong      HK     62.01     overcast clouds  22.2855
# 40                Kahului      US     72.00          few clouds  20.8947
# 41        Arraial do Cabo      BR     87.80    scattered clouds -22.9661
# 43               Sterling      US     42.01     overcast clouds  39.0062
# 44                  Pisco      PE     73.40           clear sky -13.7000
# 45                Ternate      ID     78.64          light rain   0.8000
# 46                Kavieng      PG     82.99     overcast clouds  -2.5744
#
#          Lng                                         Hotel Name
# 0  -120.4579                         Holiday Inn Express Lompoc
# 1   115.3333                            Observatory Guest House
# 3    -6.3865                                         Caladh Inn
# 5   135.8667                                 Port Lincoln Hotel
# 6   -17.9182                                      Valle Aridane
# 8   108.1000                                    Hotel Saigon-PT
# 9   -70.9167                          Hotel Dreams Del Estrecho
# 13  147.0587                    The Shingles Riverside Cottages
# 14  102.2655                               Grage Hotel Bengkulu
# 15  -57.5575                           Gran Hotel Mar del Plata
# 16 -155.0900                                Hilo Hawaiian Hotel
# 17  172.7902                                 Isles Sunset Lodge
# 18   92.7500                  Welcomhotel Bay Island Port Blair
# 19  -68.3000                                     Albatros Hotel
# 20  -54.3333                                    Beleza Pura B&B
# 23 -134.9692                                     Pension Maro'i
# 24  121.9000                              Hospitality Esperance
# 25  -39.9167                 Sea Lounge! Bar, Club & Restaurant
# 27  159.9500                                Heritage Park Hotel
# 28  133.8833                         Desert Palms Alice Springs
# 29  -63.1767                     Hotel Residencial La Pichincha
# 31  140.7667                              Commodore on the Park
# 34  -16.8500       Quinta Splendida Wellness & Botanical Garden
# 35 -122.6762         Embassy Suites by Hilton Portland Downtown
# 36  125.2833                     Hotel Atoll Emerald Miyakojima
# 37 -151.7500                 Bora-Bora Pearl Beach Resort & Spa
# 38  -28.7000                                Quinta da Meia Eira
# 39  114.1577                                 Mini Hotel Central
# 40 -156.4700                                 Maui Seaside Hotel
# 41  -42.0278                                Pousada Porto Praia
# 43  -77.4286  Hampton Inn & Suites Washington-Dulles Interna...
# 44  -76.2167                           Hotel San Isidro Oficial
# 45  127.4000                           Grand Dafam Bela Ternate
# 46  150.7967                                Nusa Island Retreat

# %%
# 8a. Create the output File (CSV)
output_data_file = 'WeatherPy_vacation.csv'
# 8b. Export the City_Data into a csv
clean_hotel_df.to_csv(output_data_file, index_label="City_ID")

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
<dt>Weather Description</dt><dd>{Current Description}</dd>
</dl>
"""

# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = clean_hotel_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map. 
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)

# 11b. Display the figure
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
fig.add_layer(marker_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
