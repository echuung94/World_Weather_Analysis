# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
cities=[]

for coordinate in coordinates: 
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities: 
        cities.append(city)
        
len(cities)
# Out:
# 615

# %%
import requests
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ddf9df14b279ded879874272a62ef85b

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    city_weather = requests.get(city_url)
    json = city_weather.json()
    print(json)
    try:
        city_data.append({
            'City' : json['name'],
            'Country' : json['sys']['country'],
            'Lat' : json['coord']['lat'],
            'Lng' : json['coord']['lon'],
            'Max Temp' : json['main']['temp_max'],
            'Humidity' : json['main']['humidity'],
            'Cloudiness' : json['clouds']['all'],
            'Wind Speed' : json['wind']['speed'],
            'Current Description' : json['weather'][0]['description']
        })
    
    except Exception as e:
    #except:
        #print("City not found. Skipping...")
        #pass
        print (e) 
         

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | lompoc
# {'coord': {'lon': -120.4579, 'lat': 34.6391}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 57.87, 'feels_like': 53.1, 'temp_min': 44.6, 'temp_max': 69.8, 'pressure': 1019, 'humidity': 76}, 'visibility': 10000, 'wind': {'speed': 8.79, 'deg': 5}, 'clouds': {'all': 21}, 'dt': 1610814300, 'sys': {'type': 1, 'id': 4747, 'country': 'US', 'sunrise': 1610809681, 'sunset': 1610846102}, 'timezone': -28800, 'id': 5367788, 'name': 'Lompoc', 'cod': 200}
# Processing Record 2 of Set 1 | busselton
# {'coord': {'lon': 115.3333, 'lat': -33.65}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 61.88, 'feels_like': 58.91, 'temp_min': 60.01, 'temp_max': 63, 'pressure': 1020, 'humidity': 68}, 'visibility': 10000, 'wind': {'speed': 5.99, 'deg': 62, 'gust': 11.01}, 'clouds': {'all': 0}, 'dt': 1610814300, 'sys': {'type': 3, 'id': 2008303, 'country': 'AU', 'sunrise': 1610832335, 'sunset': 1610883082}, 'timezone': 28800, 'id': 2075265, 'name': 'Busselton', 'cod': 200}
# Processing Record 3 of Set 1 | tuktoyaktuk
# {'coord': {'lon': -133.0374, 'lat': 69.4541}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13n'}], 'base': 'stations', 'main': {'temp': -4, 'feels_like': -17.1, 'temp_min': -4, 'temp_max': -4, 'pressure': 1016, 'humidity': 77}, 'visibility': 9656, 'wind': {'speed': 11.5, 'deg': 130}, 'clouds': {'all': 90}, 'dt': 1610814300, 'sys': {'type': 1, 'id': 942, 'country': 'CA', 'sunrise': 1610827570, 'sunset': 1610834253}, 'timezone': -25200, 'id': 6170031, 'name': 'Tuktoyaktuk', 'cod': 200}
# Processing Record 4 of Set 1 | stornoway
# {'coord': {'lon': -6.3865, 'lat': 58.2093}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 44.35, 'feels_like': 27.64, 'temp_min': 44.01, 'temp_max': 44.6, 'pressure': 1002, 'humidity': 81}, 'visibility': 10000, 'wind': {'speed': 25.32, 'deg': 270}, 'clouds': {'all': 75}, 'dt': 1610814301, 'sys': {'type': 1, 'id': 1450, 'country': 'GB', 'sunrise': 1610787524, 'sunset': 1610813491}, 'timezone': 0, 'id': 2636790, 'name': 'Stornoway', 'cod': 200}
# Processing Record 5 of Set 1 | saskylakh
# {'coord': {'lon': 114.0833, 'lat': 71.9167}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': -11.79, 'feels_like': -23.21, 'temp_min': -11.79, 'temp_max': -11.79, 'pressure': 1030, 'humidity': 89, 'sea_level': 1030, 'grnd_level': 1029}, 'visibility': 632, 'wind': {'speed': 8.28, 'deg': 36}, 'clouds': {'all': 100}, 'dt': 1610814301, 'sys': {'country': 'RU', 'sunrise': 0, 'sunset': 0}, 'timezone': 32400, 'id': 2017155, 'name': 'Saskylakh', 'cod': 200}
# Processing Record 6 of Set 1 | taolanaro
# {'cod': '404', 'message': 'city not found'}
# 'name'
# Processing Record 7 of Set 1 | port lincoln
# {'coord': {'lon': 135.8667, 'lat': -34.7333}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 60.78, 'feels_like': 57.34, 'temp_min': 60.78, 'temp_max': 60.78, 'pressure': 1022, 'humidity': 75, 'sea_level': 1022, 'grnd_level': 1020}, 'visibility': 10000, 'wind': {'speed': 7.65, 'deg': 177}, 'clouds': {'all': 85}, 'dt': 1610814301, 'sys': {'country': 'AU', 'sunrise': 1610827250, 'sunset': 1610878309}, 'timezone': 37800, 'id': 2063036, 'name': 'Port Lincoln', 'cod': 200}
# Processing Record 8 of Set 1 | los llanos de aridane
# {'coord': {'lon': -17.9182, 'lat': 28.6585}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 62.53, 'feels_like': 57.47, 'temp_min': 59, 'temp_max': 68, 'pressure': 1025, 'humidity': 64}, 'visibility': 10000, 'wind': {'speed': 9.22, 'deg': 30}, 'clouds': {'all': 20}, 'dt': 1610814301, 'sys': {'type': 1, 'id': 2377, 'country': 'ES', 'sunrise': 1610784317, 'sunset': 1610822235}, 'timezone': 0, 'id': 2514651, 'name': 'Los Llanos de Aridane', 'cod': 200}
# Processing Record 9 of Set 1 | kodiak
# {'coord': {'lon': -152.4072, 'lat': 57.79}, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10n'}, {'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50n'}], 'base': 'stations', 'main': {'temp': 39.2, 'feels_like': 17.69, 'temp_min': 39.2, 'temp_max': 39.2, 'pressure': 985, 'humidity': 93}, 'visibility': 4828, 'wind': {'speed': 33.38, 'deg': 60, 'gust': 44.87}, 'rain': {'1h': 2.54}, 'clouds': {'all': 90}, 'dt': 1610814301, 'sys': {'type': 1, 'id': 7668, 'country': 'US', 'sunrise': 1610822374, 'sunset': 1610848749}, 'timezone': -32400, 'id': 5866583, 'name': 'Saint Paul Harbor', 'cod': 200}
# Processing Record 10 of Set 1 | phan thiet
# {'coord': {'lon': 108.1, 'lat': 10.9333}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 70.09, 'feels_like': 71.53, 'temp_min': 70.09, 'temp_max': 70.09, 'pressure': 1012, 'humidity': 86, 'sea_level': 1012, 'grnd_level': 1011}, 'visibility': 10000, 'wind': {'speed': 7.38, 'deg': 50}, 'clouds': {'all': 99}, 'dt': 1610814301, 'sys': {'country': 'VN', 'sunrise': 1610752225, 'sunset': 1610793824}, 'timezone': 25200, 'id': 1571058, 'name': 'Phan Thiet', 'cod': 200}
# Processing Record 11 of Set 1 | punta arenas
# {'coord': {'lon': -70.9167, 'lat': -53.15}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 60.39, 'feels_like': 47.79, 'temp_min': 60.01, 'temp_max': 60.8, 'pressure': 1011, 'humidity': 59}, 'visibility': 10000, 'wind': {'speed': 20.71, 'deg': 280}, 'clouds': {'all': 90}, 'dt': 1610814253, 'sys': {'type': 1, 'id': 8487, 'country': 'CL', 'sunrise': 1610786649, 'sunset': 1610845349}, 'timezone': -10800, 'id': 3874787, 'name': 'Punta Arenas', 'cod': 200}
# Processing Record 12 of Set 1 | komsomolets
# {'coord': {'lon': 62.0708, 'lat': 53.7453}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 21.45, 'feels_like': 8.82, 'temp_min': 21.45, 'temp_max': 21.45, 'pressure': 1008, 'humidity': 94, 'sea_level': 1008, 'grnd_level': 987}, 'visibility': 10000, 'wind': {'speed': 13.56, 'deg': 243}, 'clouds': {'all': 38}, 'dt': 1610814302, 'sys': {'country': 'KZ', 'sunrise': 1610769599, 'sunset': 1610798550}, 'timezone': 21600, 'id': 1522348, 'name': 'Komsomolets', 'cod': 200}
# Processing Record 13 of Set 1 | sheksna
# {'coord': {'lon': 38.5107, 'lat': 59.21}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': -7.6, 'feels_like': -19.35, 'temp_min': -7.6, 'temp_max': -7.6, 'pressure': 1009, 'humidity': 77}, 'visibility': 10000, 'wind': {'speed': 8.95, 'deg': 350}, 'clouds': {'all': 0}, 'dt': 1610814302, 'sys': {'type': 1, 'id': 8931, 'country': 'RU', 'sunrise': 1610777170, 'sunset': 1610802290}, 'timezone': 10800, 'id': 495062, 'name': 'Sheksna', 'cod': 200}
# Processing Record 14 of Set 1 | flin flon
# {'coord': {'lon': -101.865, 'lat': 54.7682}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 14, 'feels_like': 5.13, 'temp_min': 14, 'temp_max': 14, 'pressure': 1004, 'humidity': 92}, 'visibility': 10000, 'wind': {'speed': 5.75, 'deg': 200}, 'clouds': {'all': 75}, 'dt': 1610814302, 'sys': {'type': 1, 'id': 782, 'country': 'CA', 'sunrise': 1610809222, 'sunset': 1610837635}, 'timezone': -21600, 'id': 5954718, 'name': 'Flin Flon', 'cod': 200}
# Processing Record 15 of Set 1 | new norfolk
# {'coord': {'lon': 147.0587, 'lat': -42.7826}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 46.94, 'feels_like': 42.96, 'temp_min': 44.01, 'temp_max': 48.99, 'pressure': 1007, 'humidity': 67}, 'visibility': 10000, 'wind': {'speed': 1.99, 'deg': 133, 'gust': 4}, 'clouds': {'all': 38}, 'dt': 1610814302, 'sys': {'type': 3, 'id': 2031307, 'country': 'AU', 'sunrise': 1610823247, 'sunset': 1610876939}, 'timezone': 39600, 'id': 2155415, 'name': 'New Norfolk', 'cod': 200}
# Processing Record 16 of Set 1 | bengkulu
# {'coord': {'lon': 102.2655, 'lat': -3.8004}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 77.94, 'feels_like': 84.25, 'temp_min': 77.94, 'temp_max': 77.94, 'pressure': 1010, 'humidity': 80, 'sea_level': 1010, 'grnd_level': 1008}, 'visibility': 10000, 'wind': {'speed': 3.49, 'deg': 31}, 'clouds': {'all': 100}, 'dt': 1610814302, 'sys': {'country': 'ID', 'sunrise': 1610752261, 'sunset': 1610796589}, 'timezone': 25200, 'id': 1649150, 'name': 'Bengkulu', 'cod': 200}
# Processing Record 17 of Set 1 | mar del plata
# {'coord': {'lon': -57.5575, 'lat': -38.0023}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 69.8, 'feels_like': 71.91, 'temp_min': 69.8, 'temp_max': 69.8, 'pressure': 1005, 'humidity': 94}, 'visibility': 5000, 'wind': {'speed': 8.05, 'deg': 180}, 'clouds': {'all': 75}, 'dt': 1610814120, 'sys': {'type': 1, 'id': 8305, 'country': 'AR', 'sunrise': 1610786749, 'sunset': 1610838835}, 'timezone': -10800, 'id': 3430863, 'name': 'Mar del Plata', 'cod': 200}
# Processing Record 18 of Set 1 | hilo
# {'coord': {'lon': -155.09, 'lat': 19.7297}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 66.02, 'feels_like': 64.36, 'temp_min': 64, 'temp_max': 68, 'pressure': 1016, 'humidity': 73}, 'visibility': 10000, 'wind': {'speed': 6.91, 'deg': 210}, 'clouds': {'all': 90}, 'dt': 1610814087, 'sys': {'type': 1, 'id': 7881, 'country': 'US', 'sunrise': 1610816257, 'sunset': 1610856153}, 'timezone': -36000, 'id': 5855927, 'name': 'Hilo', 'cod': 200}
# Processing Record 19 of Set 1 | grand centre
# {'cod': '404', 'message': 'city not found'}
# 'name'
# Processing Record 20 of Set 1 | butaritari
# {'coord': {'lon': 172.7902, 'lat': 3.0707}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 80.65, 'feels_like': 78.39, 'temp_min': 80.65, 'temp_max': 80.65, 'pressure': 1007, 'humidity': 79, 'sea_level': 1007, 'grnd_level': 1006}, 'visibility': 10000, 'wind': {'speed': 20.92, 'deg': 98}, 'clouds': {'all': 52}, 'dt': 1610814303, 'sys': {'country': 'KI', 'sunrise': 1610822382, 'sunset': 1610865449}, 'timezone': 43200, 'id': 2110227, 'name': 'Butaritari', 'cod': 200}
# Processing Record 21 of Set 1 | port blair
# {'coord': {'lon': 92.75, 'lat': 11.6667}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 77.74, 'feels_like': 80.17, 'temp_min': 77.74, 'temp_max': 77.74, 'pressure': 1011, 'humidity': 76, 'sea_level': 1011, 'grnd_level': 1010}, 'visibility': 10000, 'wind': {'speed': 8.84, 'deg': 51}, 'clouds': {'all': 59}, 'dt': 1610814061, 'sys': {'country': 'IN', 'sunrise': 1610755979, 'sunset': 1610797440}, 'timezone': 19800, 'id': 1259385, 'name': 'Port Blair', 'cod': 200}
# Processing Record 22 of Set 1 | ushuaia
# {'coord': {'lon': -68.3, 'lat': -54.8}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 60.8, 'feels_like': 55.85, 'temp_min': 60.8, 'temp_max': 60.8, 'pressure': 1007, 'humidity': 63}, 'visibility': 10000, 'wind': {'speed': 8.05, 'deg': 140}, 'clouds': {'all': 40}, 'dt': 1610814090, 'sys': {'type': 1, 'id': 8303, 'country': 'AR', 'sunrise': 1610785480, 'sunset': 1610845261}, 'timezone': -10800, 'id': 3833367, 'name': 'Ushuaia', 'cod': 200}
# Processing Record 23 of Set 1 | rocha
# {'coord': {'lon': -54.3333, 'lat': -34.4833}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 83.95, 'feels_like': 82.76, 'temp_min': 83.95, 'temp_max': 83.95, 'pressure': 1003, 'humidity': 56, 'sea_level': 1003, 'grnd_level': 1000}, 'visibility': 10000, 'wind': {'speed': 12.71, 'deg': 212}, 'clouds': {'all': 48}, 'dt': 1610814303, 'sys': {'country': 'UY', 'sunrise': 1610786506, 'sunset': 1610837529}, 'timezone': -10800, 'id': 3440777, 'name': 'Rocha', 'cod': 200}
# Processing Record 24 of Set 1 | albany
# {'coord': {'lon': -73.9662, 'lat': 42.6001}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 35.6, 'feels_like': 30.18, 'temp_min': 34, 'temp_max': 36, 'pressure': 992, 'humidity': 89}, 'visibility': 1326, 'wind': {'speed': 3.47, 'deg': 277}, 'clouds': {'all': 100}, 'dt': 1610814303, 'sys': {'type': 3, 'id': 19530, 'country': 'US', 'sunrise': 1610799745, 'sunset': 1610833717}, 'timezone': -18000, 'id': 5106841, 'name': 'Albany', 'cod': 200}
# Processing Record 25 of Set 1 | ilulissat
# {'coord': {'lon': -51.1, 'lat': 69.2167}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 10.4, 'feels_like': 2.01, 'temp_min': 10.4, 'temp_max': 10.4, 'pressure': 1013, 'humidity': 52}, 'visibility': 10000, 'wind': {'speed': 3.44, 'deg': 0}, 'clouds': {'all': 1}, 'dt': 1610814303, 'sys': {'type': 1, 'id': 165, 'country': 'GL', 'sunrise': 1610807376, 'sunset': 1610815107}, 'timezone': -10800, 'id': 3423146, 'name': 'Ilulissat', 'cod': 200}
# Processing Record 26 of Set 1 | rikitea
# {'coord': {'lon': -134.9692, 'lat': -23.1203}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 77.63, 'feels_like': 82.06, 'temp_min': 77.63, 'temp_max': 77.63, 'pressure': 1018, 'humidity': 71, 'sea_level': 1018, 'grnd_level': 1015}, 'visibility': 10000, 'wind': {'speed': 3.49, 'deg': 53}, 'rain': {'1h': 0.95}, 'clouds': {'all': 31}, 'dt': 1610814303, 'sys': {'country': 'PF', 'sunrise': 1610807297, 'sunset': 1610855453}, 'timezone': -32400, 'id': 4030556, 'name': 'Rikitea', 'cod': 200}
# Processing Record 27 of Set 1 | esperance
# {'coord': {'lon': 121.9, 'lat': -33.8667}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 55.4, 'feels_like': 48.67, 'temp_min': 55.4, 'temp_max': 55.4, 'pressure': 1024, 'humidity': 71}, 'visibility': 10000, 'wind': {'speed': 10.36, 'deg': 80}, 'clouds': {'all': 0}, 'dt': 1610814303, 'sys': {'type': 1, 'id': 9525, 'country': 'AU', 'sunrise': 1610830728, 'sunset': 1610881537}, 'timezone': 28800, 'id': 2071860, 'name': 'Esperance', 'cod': 200}
# Processing Record 28 of Set 1 | palabuhanratu
# {'cod': '404', 'message': 'city not found'}
# 'name'
# Processing Record 29 of Set 1 | itarema
# {'coord': {'lon': -39.9167, 'lat': -2.9248}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 88.32, 'feels_like': 86.54, 'temp_min': 88.32, 'temp_max': 88.32, 'pressure': 1009, 'humidity': 54, 'sea_level': 1009, 'grnd_level': 1007}, 'visibility': 10000, 'wind': {'speed': 16.31, 'deg': 84}, 'clouds': {'all': 27}, 'dt': 1610814303, 'sys': {'country': 'BR', 'sunrise': 1610786476, 'sunset': 1610830639}, 'timezone': -10800, 'id': 3393692, 'name': 'Itarema', 'cod': 200}
# Processing Record 30 of Set 1 | lavrentiya
# {'coord': {'lon': -171, 'lat': 65.5833}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': -5.4, 'feels_like': -16.67, 'temp_min': -5.4, 'temp_max': -5.4, 'pressure': 1009, 'humidity': 87, 'sea_level': 1009, 'grnd_level': 1007}, 'visibility': 10000, 'wind': {'speed': 8.3, 'deg': 347}, 'clouds': {'all': 100}, 'dt': 1610814303, 'sys': {'country': 'RU', 'sunrise': 1610917385, 'sunset': 1610935503}, 'timezone': 43200, 'id': 4031637, 'name': 'Lavrentiya', 'cod': 200}
# Processing Record 31 of Set 1 | honiara
# {'coord': {'lon': 159.95, 'lat': -9.4333}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 77.22, 'feels_like': 83.86, 'temp_min': 77.22, 'temp_max': 77.22, 'pressure': 1007, 'humidity': 80, 'sea_level': 1007, 'grnd_level': 1003}, 'visibility': 10000, 'wind': {'speed': 2.26, 'deg': 151}, 'clouds': {'all': 100}, 'dt': 1610814217, 'sys': {'country': 'SB', 'sunrise': 1610824314, 'sunset': 1610869683}, 'timezone': 39600, 'id': 2108502, 'name': 'Honiara', 'cod': 200}
# Processing Record 32 of Set 1 | alice springs
# {'coord': {'lon': 133.8833, 'lat': -23.7}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 69.8, 'feels_like': 64.85, 'temp_min': 69.8, 'temp_max': 69.8, 'pressure': 1015, 'humidity': 46}, 'visibility': 10000, 'wind': {'speed': 8.05, 'deg': 110}, 'clouds': {'all': 90}, 'dt': 1610814303, 'sys': {'type': 1, 'id': 9483, 'country': 'AU', 'sunrise': 1610829119, 'sunset': 1610877392}, 'timezone': 34200, 'id': 2077895, 'name': 'Alice Springs', 'cod': 200}
# Processing Record 33 of Set 1 | maturin
# {'coord': {'lon': -63.1767, 'lat': 9.75}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 85.05, 'feels_like': 86.29, 'temp_min': 85.05, 'temp_max': 85.05, 'pressure': 1013, 'humidity': 55, 'sea_level': 1013, 'grnd_level': 1005}, 'visibility': 10000, 'wind': {'speed': 8.79, 'deg': 68}, 'clouds': {'all': 36}, 'dt': 1610814303, 'sys': {'country': 'VE', 'sunrise': 1610793225, 'sunset': 1610835056}, 'timezone': -14400, 'id': 3778045, 'name': 'Maturin', 'cod': 200}
# Processing Record 34 of Set 1 | barrow
# {'coord': {'lon': -156.7887, 'lat': 71.2906}, 'weather': [{'id': 721, 'main': 'Haze', 'description': 'haze', 'icon': '50n'}], 'base': 'stations', 'main': {'temp': -2.2, 'feels_like': -19.14, 'temp_min': -2.2, 'temp_max': -2.2, 'pressure': 1018, 'humidity': 78}, 'visibility': 4828, 'wind': {'speed': 18.41, 'deg': 50}, 'clouds': {'all': 90}, 'dt': 1610814304, 'sys': {'type': 1, 'id': 7649, 'country': 'US', 'sunrise': 0, 'sunset': 0}, 'timezone': -32400, 'id': 5880054, 'name': 'Barrow', 'cod': 200}
# Processing Record 35 of Set 1 | mount gambier
# {'coord': {'lon': 140.7667, 'lat': -37.8333}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 50, 'feels_like': 46.33, 'temp_min': 50, 'temp_max': 50, 'pressure': 1019, 'humidity': 93}, 'visibility': 10000, 'wind': {'speed': 5.75, 'deg': 300}, 'clouds': {'all': 90}, 'dt': 1610814304, 'sys': {'type': 1, 'id': 9560, 'country': 'AU', 'sunrise': 1610825607, 'sunset': 1610877599}, 'timezone': 37800, 'id': 2156643, 'name': 'Mount Gambier', 'cod': 200}
# Processing Record 36 of Set 1 | khatanga
# {'coord': {'lon': 102.5, 'lat': 71.9667}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': -26.01, 'feels_like': -35.54, 'temp_min': -26.01, 'temp_max': -26.01, 'pressure': 1033, 'humidity': 86, 'sea_level': 1033, 'grnd_level': 1029}, 'visibility': 2489, 'wind': {'speed': 4.5, 'deg': 61}, 'clouds': {'all': 95}, 'dt': 1610814304, 'sys': {'country': 'RU', 'sunrise': 0, 'sunset': 0}, 'timezone': 25200, 'id': 2022572, 'name': 'Khatanga', 'cod': 200}
# Processing Record 37 of Set 1 | upernavik
# {'coord': {'lon': -56.1549, 'lat': 72.7868}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 11.53, 'feels_like': 3.27, 'temp_min': 11.53, 'temp_max': 11.53, 'pressure': 1014, 'humidity': 92, 'sea_level': 1014, 'grnd_level': 1014}, 'visibility': 10000, 'wind': {'speed': 4.36, 'deg': 75}, 'clouds': {'all': 13}, 'dt': 1610814304, 'sys': {'country': 'GL', 'sunrise': 0, 'sunset': 0}, 'timezone': -10800, 'id': 3418910, 'name': 'Upernavik', 'cod': 200}
# Processing Record 38 of Set 1 | canico
# {'coord': {'lon': -16.85, 'lat': 32.6333}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 58.6, 'feels_like': 50.76, 'temp_min': 54, 'temp_max': 64.4, 'pressure': 1028, 'humidity': 52}, 'visibility': 10000, 'wind': {'speed': 10.36, 'deg': 360}, 'clouds': {'all': 40}, 'dt': 1610814304, 'sys': {'type': 1, 'id': 6894, 'country': 'PT', 'sunrise': 1610784554, 'sunset': 1610821486}, 'timezone': 0, 'id': 2270258, 'name': 'Caniço', 'cod': 200}
# Processing Record 39 of Set 1 | portland
# {'coord': {'lon': -122.6762, 'lat': 45.5234}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 41.36, 'feels_like': 34.52, 'temp_min': 39, 'temp_max': 43, 'pressure': 1030, 'humidity': 81}, 'visibility': 10000, 'wind': {'speed': 6.91, 'deg': 90}, 'clouds': {'all': 90}, 'dt': 1610814263, 'sys': {'type': 1, 'id': 5321, 'country': 'US', 'sunrise': 1610811967, 'sunset': 1610844881}, 'timezone': -28800, 'id': 5746545, 'name': 'Portland', 'cod': 200}
# Processing Record 40 of Set 1 | hirara
# {'coord': {'lon': 125.2833, 'lat': 24.8}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 64.94, 'feels_like': 50.74, 'temp_min': 64.94, 'temp_max': 64.94, 'pressure': 1020, 'humidity': 81, 'sea_level': 1020, 'grnd_level': 1017}, 'visibility': 10000, 'wind': {'speed': 30.36, 'deg': 26}, 'clouds': {'all': 94}, 'dt': 1610814304, 'sys': {'country': 'JP', 'sunrise': 1610835904, 'sunset': 1610874736}, 'timezone': 32400, 'id': 1862505, 'name': 'Hirara', 'cod': 200}
# Processing Record 41 of Set 1 | faanui
# {'coord': {'lon': -151.75, 'lat': -16.4833}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 81.23, 'feels_like': 83.55, 'temp_min': 81.23, 'temp_max': 81.23, 'pressure': 1013, 'humidity': 73, 'sea_level': 1013, 'grnd_level': 1013}, 'visibility': 10000, 'wind': {'speed': 11.01, 'deg': 79}, 'clouds': {'all': 10}, 'dt': 1610814305, 'sys': {'country': 'PF', 'sunrise': 1610812029, 'sunset': 1610858777}, 'timezone': -36000, 'id': 4034551, 'name': 'Faanui', 'cod': 200}
# Processing Record 42 of Set 1 | ribeira grande
# {'coord': {'lon': -28.7, 'lat': 38.5167}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 62.6, 'feels_like': 60.28, 'temp_min': 62.6, 'temp_max': 62.6, 'pressure': 1022, 'humidity': 82}, 'visibility': 10000, 'wind': {'speed': 8.05, 'deg': 140}, 'clouds': {'all': 40}, 'dt': 1610814305, 'sys': {'type': 1, 'id': 6883, 'country': 'PT', 'sunrise': 1610788221, 'sunset': 1610823508}, 'timezone': -3600, 'id': 3372707, 'name': 'Ribeira Grande', 'cod': 200}
# Processing Record 43 of Set 1 | victoria
# {'coord': {'lon': 114.1577, 'lat': 22.2855}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 59.43, 'feels_like': 58.35, 'temp_min': 50, 'temp_max': 62.01, 'pressure': 1020, 'humidity': 76}, 'visibility': 10000, 'wind': {'speed': 3, 'deg': 24, 'gust': 8.01}, 'clouds': {'all': 99}, 'dt': 1610814305, 'sys': {'type': 3, 'id': 2035800, 'country': 'HK', 'sunrise': 1610838303, 'sunset': 1610877678}, 'timezone': 28800, 'id': 1819729, 'name': 'Hong Kong', 'cod': 200}
# Processing Record 44 of Set 1 | kahului
# {'coord': {'lon': -156.47, 'lat': 20.8947}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 66.85, 'feels_like': 66, 'temp_min': 62.01, 'temp_max': 72, 'pressure': 1016, 'humidity': 72}, 'visibility': 10000, 'wind': {'speed': 5.75, 'deg': 140}, 'clouds': {'all': 20}, 'dt': 1610814304, 'sys': {'type': 1, 'id': 7879, 'country': 'US', 'sunrise': 1610816708, 'sunset': 1610856364}, 'timezone': -36000, 'id': 5847411, 'name': 'Kahului', 'cod': 200}
# Processing Record 45 of Set 1 | arraial do cabo
# {'coord': {'lon': -42.0278, 'lat': -22.9661}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 86.77, 'feels_like': 82.83, 'temp_min': 86, 'temp_max': 87.8, 'pressure': 1012, 'humidity': 58}, 'visibility': 10000, 'wind': {'speed': 20.71, 'deg': 60, 'gust': 34.52}, 'clouds': {'all': 40}, 'dt': 1610814305, 'sys': {'type': 1, 'id': 8326, 'country': 'BR', 'sunrise': 1610784997, 'sunset': 1610833131}, 'timezone': -10800, 'id': 3471451, 'name': 'Arraial do Cabo', 'cod': 200}
# Processing Record 46 of Set 1 | fort saint john
# {'cod': '404', 'message': 'city not found'}
# 'name'
# Processing Record 47 of Set 1 | cherskiy
# {'coord': {'lon': 161.3, 'lat': 68.75}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': -20.74, 'feels_like': -30.14, 'temp_min': -20.74, 'temp_max': -20.74, 'pressure': 1025, 'humidity': 87, 'sea_level': 1025, 'grnd_level': 1025}, 'visibility': 314, 'wind': {'speed': 4.41, 'deg': 225}, 'clouds': {'all': 100}, 'dt': 1610814305, 'sys': {'country': 'RU', 'sunrise': 1610841629, 'sunset': 1610851719}, 'timezone': 39600, 'id': 2126199, 'name': 'Cherskiy', 'cod': 200}
# Processing Record 48 of Set 1 | sterling
# {'coord': {'lon': -77.4286, 'lat': 39.0062}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 40.24, 'feels_like': 29.84, 'temp_min': 37.99, 'temp_max': 42.01, 'pressure': 1001, 'humidity': 65}, 'visibility': 10000, 'wind': {'speed': 11.5, 'deg': 320}, 'clouds': {'all': 90}, 'dt': 1610814103, 'sys': {'type': 1, 'id': 4481, 'country': 'US', 'sunrise': 1610799988, 'sunset': 1610835136}, 'timezone': -18000, 'id': 4787534, 'name': 'Sterling', 'cod': 200}
# Processing Record 49 of Set 1 | pisco
# {'coord': {'lon': -76.2167, 'lat': -13.7}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 73.4, 'feels_like': 73.15, 'temp_min': 73.4, 'temp_max': 73.4, 'pressure': 1012, 'humidity': 73}, 'visibility': 10000, 'wind': {'speed': 9.22, 'deg': 300}, 'clouds': {'all': 0}, 'dt': 1610814305, 'sys': {'type': 1, 'id': 8691, 'country': 'PE', 'sunrise': 1610794172, 'sunset': 1610840371}, 'timezone': -18000, 'id': 3932145, 'name': 'Pisco', 'cod': 200}
# Processing Record 50 of Set 1 | ternate
# {'coord': {'lon': 127.4, 'lat': 0.8}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 78.64, 'feels_like': 86.61, 'temp_min': 78.64, 'temp_max': 78.64, 'pressure': 1006, 'humidity': 84, 'sea_level': 1006, 'grnd_level': 1006}, 'visibility': 10000, 'wind': {'speed': 2.59, 'deg': 319}, 'rain': {'1h': 0.365}, 'clouds': {'all': 100}, 'dt': 1610814305, 'sys': {'country': 'ID', 'sunrise': 1610833072, 'sunset': 1610876552}, 'timezone': 32400, 'id': 1624041, 'name': 'Ternate', 'cod': 200}
# Processing Record 1 of Set 2 | kavieng
# {'coord': {'lon': 150.7967, 'lat': -2.5744}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 82.99, 'feels_like': 84.67, 'temp_min': 82.99, 'temp_max': 82.99, 'pressure': 1005, 'humidity': 80, 'sea_level': 1005, 'grnd_level': 1004}, 'visibility': 10000, 'wind': {'speed': 16.64, 'deg': 78}, 'clouds': {'all': 93}, 'dt': 1610814305, 'sys': {'country': 'PG', 'sunrise': 1610827147, 'sunset': 1610871243}, 'timezone': 36000, 'id': 2094342, 'name': 'Kavieng', 'cod': 200}
# Processing Record 2 of Set 2 | hermanus
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-46215ac3da4a> in <module>
#      14     print(f"Processing Record {record_count} of Set {set_count} | {city}")
#      15     record_count += 1
# ---> 16     city_weather = requests.get(city_url)
#      17     json = city_weather.json()
#      18     print(json)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~\anaconda3\envs\PythonData\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\anaconda3\envs\PythonData\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~\anaconda3\envs\PythonData\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~\anaconda3\envs\PythonData\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     675                 body=body,
#     676                 headers=headers,
# --> 677                 chunked=chunked,
#     678             )
#     679
#
# ~\anaconda3\envs\PythonData\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     424                     # Python 3 (including for exceptions like SystemExit).
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                 # Python 3
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#     423                     # Remove the TypeError from the exception chain in
#
# ~\anaconda3\envs\PythonData\lib\http\client.py in getresponse(self)
#    1367         try:
#    1368             try:
# -> 1369                 response.begin()
#    1370             except ConnectionError:
#    1371                 self.close()
#
# ~\anaconda3\envs\PythonData\lib\http\client.py in begin(self)
#     308         # read until we get a non-100 response
#     309         while True:
# --> 310             version, status, reason = self._read_status()
#     311             if status != CONTINUE:
#     312                 break
#
# ~\anaconda3\envs\PythonData\lib\http\client.py in _read_status(self)
#     269
#     270     def _read_status(self):
# --> 271         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     272         if len(line) > _MAXLINE:
#     273             raise LineTooLong("status line")
#
# ~\anaconda3\envs\PythonData\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                      City Country      Lat       Lng  Max Temp  Humidity  \
# 0                  Lompoc      US  34.6391 -120.4579     69.80        76
# 1               Busselton      AU -33.6500  115.3333     63.00        68
# 2             Tuktoyaktuk      CA  69.4541 -133.0374     -4.00        77
# 3               Stornoway      GB  58.2093   -6.3865     44.60        81
# 4               Saskylakh      RU  71.9167  114.0833    -11.79        89
# 5            Port Lincoln      AU -34.7333  135.8667     60.78        75
# 6   Los Llanos de Aridane      ES  28.6585  -17.9182     68.00        64
# 7       Saint Paul Harbor      US  57.7900 -152.4072     39.20        93
# 8              Phan Thiet      VN  10.9333  108.1000     70.09        86
# 9            Punta Arenas      CL -53.1500  -70.9167     60.80        59
# 10            Komsomolets      KZ  53.7453   62.0708     21.45        94
# 11                Sheksna      RU  59.2100   38.5107     -7.60        77
# 12              Flin Flon      CA  54.7682 -101.8650     14.00        92
# 13            New Norfolk      AU -42.7826  147.0587     48.99        67
# 14               Bengkulu      ID  -3.8004  102.2655     77.94        80
# 15          Mar del Plata      AR -38.0023  -57.5575     69.80        94
# 16                   Hilo      US  19.7297 -155.0900     68.00        73
# 17             Butaritari      KI   3.0707  172.7902     80.65        79
# 18             Port Blair      IN  11.6667   92.7500     77.74        76
# 19                Ushuaia      AR -54.8000  -68.3000     60.80        63
# 20                  Rocha      UY -34.4833  -54.3333     83.95        56
# 21                 Albany      US  42.6001  -73.9662     36.00        89
# 22              Ilulissat      GL  69.2167  -51.1000     10.40        52
# 23                Rikitea      PF -23.1203 -134.9692     77.63        71
# 24              Esperance      AU -33.8667  121.9000     55.40        71
# 25                Itarema      BR  -2.9248  -39.9167     88.32        54
# 26             Lavrentiya      RU  65.5833 -171.0000     -5.40        87
# 27                Honiara      SB  -9.4333  159.9500     77.22        80
# 28          Alice Springs      AU -23.7000  133.8833     69.80        46
# 29                Maturin      VE   9.7500  -63.1767     85.05        55
# 30                 Barrow      US  71.2906 -156.7887     -2.20        78
# 31          Mount Gambier      AU -37.8333  140.7667     50.00        93
# 32               Khatanga      RU  71.9667  102.5000    -26.01        86
# 33              Upernavik      GL  72.7868  -56.1549     11.53        92
# 34                 Caniço      PT  32.6333  -16.8500     64.40        52
# 35               Portland      US  45.5234 -122.6762     43.00        81
# 36                 Hirara      JP  24.8000  125.2833     64.94        81
# 37                 Faanui      PF -16.4833 -151.7500     81.23        73
# 38         Ribeira Grande      PT  38.5167  -28.7000     62.60        82
# 39              Hong Kong      HK  22.2855  114.1577     62.01        76
# 40                Kahului      US  20.8947 -156.4700     72.00        72
# 41        Arraial do Cabo      BR -22.9661  -42.0278     87.80        58
# 42               Cherskiy      RU  68.7500  161.3000    -20.74        87
# 43               Sterling      US  39.0062  -77.4286     42.01        65
# 44                  Pisco      PE -13.7000  -76.2167     73.40        73
# 45                Ternate      ID   0.8000  127.4000     78.64        84
# 46                Kavieng      PG  -2.5744  150.7967     82.99        80
#
#     Cloudiness  Wind Speed Current Description
# 0           21        8.79          few clouds
# 1            0        5.99           clear sky
# 2           90       11.50          light snow
# 3           75       25.32       broken clouds
# 4          100        8.28     overcast clouds
# 5           85        7.65     overcast clouds
# 6           20        9.22          few clouds
# 7           90       33.38       moderate rain
# 8           99        7.38     overcast clouds
# 9           90       20.71     overcast clouds
# 10          38       13.56    scattered clouds
# 11           0        8.95           clear sky
# 12          75        5.75       broken clouds
# 13          38        1.99    scattered clouds
# 14         100        3.49     overcast clouds
# 15          75        8.05       broken clouds
# 16          90        6.91     overcast clouds
# 17          52       20.92       broken clouds
# 18          59        8.84       broken clouds
# 19          40        8.05    scattered clouds
# 20          48       12.71    scattered clouds
# 21         100        3.47     overcast clouds
# 22           1        3.44           clear sky
# 23          31        3.49          light rain
# 24           0       10.36           clear sky
# 25          27       16.31    scattered clouds
# 26         100        8.30     overcast clouds
# 27         100        2.26     overcast clouds
# 28          90        8.05     overcast clouds
# 29          36        8.79    scattered clouds
# 30          90       18.41                haze
# 31          90        5.75     overcast clouds
# 32          95        4.50     overcast clouds
# 33          13        4.36          few clouds
# 34          40       10.36    scattered clouds
# 35          90        6.91     overcast clouds
# 36          94       30.36     overcast clouds
# 37          10       11.01           clear sky
# 38          40        8.05    scattered clouds
# 39          99        3.00     overcast clouds
# 40          20        5.75          few clouds
# 41          40       20.71    scattered clouds
# 42         100        4.41     overcast clouds
# 43          90       11.50     overcast clouds
# 44           0        9.22           clear sky
# 45         100        2.59          light rain
# 46          93       16.64     overcast clouds

# %%
city_data_df.to_csv('WeatherPy_Database.csv')
